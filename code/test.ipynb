# %%
from insta_crawling import crawling_start

# %%
df = crawling_start('아이유', 2, mongo_save=0)
df.tail(5)
# Out:
# id를 입력하세요: yeejun90
# password를 입력하세요: ········
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-b7ecb77951ea> in <module>
# ----> 1 df = crawling_start('아이유', 2, mongo_save=0)
#       2 df.tail(5)
#
# ~/Desktop/Fastcampus/dss01/crawling_project/insta_crawling.py in crawling_start(keyword, repeat_num, mongo_save)
#     223     insta = instagram_crawling()
#     224
# --> 225     insta.login()
#     226     insta.input_keyword(keyword)
#     227
#
# ~/Desktop/Fastcampus/dss01/crawling_project/insta_crawling.py in login(self)
#      65         # 알림설정 하라는 modal창이 뜨는경우 '나중에 하기'를 클릭하는 코드
#      66         start_time = time.time()
# ---> 67         alert_modal = self.check_response(self.driver, 'body > div.RnEpo.Yx5HN > div > div', 'login', start_time)
#      68         if alert_modal == False:
# ...
